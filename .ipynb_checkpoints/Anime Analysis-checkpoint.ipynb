# %% [markdown]
# # Anime Analysis

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import re
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_pickle("anime_df.pkl")
#df.to_pickle("anime_df.pkl")

# %%
df
# Out:
#        Rating    Votes                                              Title  \
# 0       9.410  73986.0                   Fullmetal Alchemist: Brotherhood
# 1       9.356  29247.0                                         your name.
# 2       9.334  19592.0                                     A Silent Voice
# 3       9.320  11195.0  Haikyuu!! Karasuno High School vs Shiratorizaw...
# 4       9.296  18788.0                                 My Hero Academia 3
# 5       9.288   2939.0                                  Mob Psycho 100 II
# 6       9.274  15322.0                            Haikyuu!! Second Season
# 7       9.266   5375.0        Gintama Kanketsu-hen: Yorozuya yo Eien Nare
# 8       9.264  29623.0                                 My Hero Academia 2
# 9       9.262   6192.0                                     Gintama (2015)
# 10      9.256  42599.0                                        Steins;Gate
# 11      9.256  35732.0                             Hunter x Hunter (2011)
# 12      9.248   1248.0              Gintama.: Shirogane no Tamashii-hen 2
# 13      9.246   4144.0                             The Promised Neverland
# 14      9.240  59301.0            Code Geass: Lelouch of the Rebellion R2
# 15      9.228   2430.0              March Comes in like a Lion 2nd Season
# 16      9.222   3497.0                                           Gintama.
# 17      9.218   5109.0                      Mushishi Zoku Shou 2nd Season
# 18      9.210   1803.0                Gintama.: Shirogane no Tamashii-hen
# 19      9.200   9542.0                                           Gintama'
# 20      9.198   7238.0                                Gintama': Enchousen
# 21      9.196  48807.0                                      One-Punch Man
# 22      9.196  38709.0                                Clannad After Story
# 23      9.192   2718.0                            Natsume Yuujinchou Roku
# 24      9.184   6015.0                                 Mushishi Zoku Shou
# 25      9.178  10098.0                                      Made in Abyss
# 26      9.176  21464.0                                      Wolf Children
# 27      9.164  71965.0                                      Spirited Away
# 28      9.162   1359.0                        I Want to Eat Your Pancreas
# 29      9.158   5336.0                      The Rising of the Shield Hero
# ...       ...      ...                                                ...
# 12651     NaN      NaN     Kaiketsu Zorori Movie 3: Uchuu no Yuusha-tachi
# 12652     NaN      NaN                     Kantai Collection: Kan Colle 2
# 12653     NaN      NaN                                     Shishou Series
# 12654     NaN      NaN                                    Kaseifu ga Ita.
# 12655     NaN      NaN                                          Inui-san!
# 12656     NaN      NaN                             Yuuto-kun ga Iku Movie
# 12657     NaN      NaN                        Shimajirou to Kujira no Uta
# 12658     NaN      NaN                     Himitsukessha Taka no Tsume EX
# 12659     NaN      NaN                    Himitsukessha Taka no Tsume MAX
# 12660     NaN      NaN                                    Boku wa Ou-sama
# 12661     NaN      NaN                                           Aoki Uru
# 12662     NaN      NaN                          Kurumiwari Ningyou (2014)
# 12663     NaN      NaN                            Ticonderonga no Iru Umi
# 12664     NaN      NaN                                          Ehon Yose
# 12665     NaN      NaN                              Choujikuu Robo Meguru
# 12666     NaN      NaN                                     Mecha Afro-kun
# 12667     NaN      NaN          Tensai Bakavon: Yomigaeru Flanders no Inu
# 12668     NaN      NaN                Spo-chan Taiketsu: Youkai Daikessen
# 12669     NaN      NaN                                       Kotenkotenko
# 12670     NaN      NaN                                        Project 758
# 12671     NaN      NaN                                         Tsubu★Doll
# 12672     NaN      NaN                                            Washimo
# 12673     NaN      NaN                                               Mint
# 12674     NaN      NaN                                   Odoriko Clinoppe
# 12675     NaN      NaN                                     Paboo & Mojies
# 12676     NaN      NaN                           Magical Suite Prism Nana
# 12677     NaN      NaN                                        Girls' Work
# 12678     NaN      NaN                                    Yume Miru Kikai
# 12679     NaN      NaN                                        Cencoroll 2
# 12680     NaN      NaN                       Rebuild of Evangelion: Final
#
#                                                Alt Title Format  Episodes  \
# 0         Hagane no Renkinjutsushi: Full Metal Alchemist     TV      64.0
# 1                                         Kimi no Na wa.  Movie       1.0
# 2                                         Koe no Katachi  Movie       1.0
# 3       Haikyuu!! 3rd Season: Karasuno High vs. Shira...     TV      10.0
# 4                                Boku no Hero Academia 3     TV      25.0
# 5                                                    NaN     TV      12.0
# 6                                                    NaN     TV      25.0
# 7      Gintama The Movie: The Final Chapter - Be Fore...  Movie       1.0
# 8                                Boku no Hero Academia 2     TV      25.0
# 9                                               Gintama°     TV      51.0
# 10                                                   NaN     TV      24.0
# 11                                                   NaN     TV     148.0
# 12                            Gintama: Silver Soul Arc 2     TV      14.0
# 13                                 Yakusoku no Neverland     TV      12.0
# 14                    Code Geass: Hangyaku no Lelouch R2     TV      25.0
# 15                            3-gatsu no Lion 2nd Season     TV      22.0
# 16                                                   NaN     TV      12.0
# 17                    Mushishi -Next Passage- 2nd Season     TV      10.0
# 18                              Gintama: Silver Soul Arc     TV      12.0
# 19                                       Gintama' (2011)     TV      51.0
# 20                                                   NaN     TV      13.0
# 21                                                   NaN     TV      12.0
# 22                                                   NaN     TV      24.0
# 23                    Natsume's Book of Friends Season 6     TV      11.0
# 24                               Mushishi -Next Passage-     TV      10.0
# 25                                                   NaN     TV      13.0
# 26                          Ookami Kodomo no Ame to Yuki  Movie       1.0
# 27                         Sen to Chihiro no Kamikakushi  Movie       1.0
# 28                             Kimi no Suizou wo Tabetai  Movie       1.0
# 29                           Tate no Yuusha no Nariagari     TV      12.0
# ...                                                  ...    ...       ...
# 12651                                                NaN  Movie       1.0
# 12652                                                NaN     TV       NaN
# 12653                                                NaN     TV       NaN
# 12654                                                NaN    OVA       1.0
# 12655                                                NaN    OVA       2.0
# 12656                        Gekijouban Yuuto-kun ga Iku  Movie       1.0
# 12657                                                NaN  Movie       1.0
# 12658                                     Eagle Talon EX     TV      38.0
# 12659                                    Eagle Talon MAX     TV      38.0
# 12660                                                NaN     TV      12.0
# 12661                                        Uru in Blue  Movie       NaN
# 12662                          Nutcracker Fantasy (2014)  Movie       1.0
# 12663                                                NaN    OVA       1.0
# 12664                                                NaN     TV      50.0
# 12665                         Hyperdimension Robo Meguru  Other       NaN
# 12666                    Cyborg Salaryman Mecha Afro-kun    OVA       1.0
# 12667                                                NaN  Movie       1.0
# 12668                                                NaN  Movie       1.0
# 12669                                                NaN     TV      52.0
# 12670                                                NaN  Other       NaN
# 12671                                                NaN    OVA       NaN
# 12672                                                NaN     TV      10.0
# 12673                                                NaN  Movie       NaN
# 12674                                                NaN     TV      26.0
# 12675                                                NaN     TV      52.0
# 12676                                                NaN    OVA       2.0
# 12677                                                NaN  Other       NaN
# 12678                                  The Dream Machine  Movie       NaN
# 12679                                                NaN  Movie       NaN
# 12680   Shin Evangelion Gekijou-ban :||, Shin Evangel...  Movie       NaN
#
#        Duration Start Year End Year                          Studio  \
# 0           NaN     2009.0   2010.0                         [Bones]
# 1         107.0     2016.0   2016.0               [CoMix Wave Inc.]
# 2         130.0     2016.0   2016.0               [Kyoto Animation]
# 3           NaN     2016.0   2016.0                [Production I.G]
# 4           NaN     2018.0   2018.0                         [Bones]
# 5           NaN     2019.0      NaN                         [Bones]
# 6           NaN     2015.0   2016.0                [Production I.G]
# 7         111.0     2013.0   2013.0                       [Sunrise]
# 8           NaN     2017.0   2017.0                         [Bones]
# 9           NaN     2015.0   2016.0                   [BN Pictures]
# 10          NaN     2011.0   2011.0                     [WHITE FOX]
# 11          NaN     2011.0   2014.0                      [MADHOUSE]
# 12          NaN     2018.0   2018.0                   [BN Pictures]
# 13          NaN     2019.0   2019.0                   [CloverWorks]
# 14          NaN     2008.0   2008.0                       [Sunrise]
# 15          NaN     2017.0   2018.0                         [Shaft]
# 16          NaN     2017.0   2017.0                   [BN Pictures]
# 17          NaN     2014.0   2014.0                       [Artland]
# 18          NaN     2018.0   2018.0                   [BN Pictures]
# 19          NaN     2011.0   2012.0                       [Sunrise]
# 20          NaN     2012.0   2013.0                       [Sunrise]
# 21          NaN     2015.0   2015.0                      [MADHOUSE]
# 22          NaN     2008.0   2009.0               [Kyoto Animation]
# 23          NaN     2017.0   2017.0                         [Shuka]
# 24          NaN     2014.0   2014.0                       [Artland]
# 25          NaN     2017.0   2017.0                 [Kinema Citrus]
# 26        117.0     2012.0   2012.0                  [Studio Chizu]
# 27        125.0     2001.0   2001.0                 [Studio Ghibli]
# 28        120.0     2018.0   2018.0                   [Studio VOLN]
# 29          NaN     2019.0      NaN                 [Kinema Citrus]
# ...         ...        ...      ...                             ...
# 12651      49.0     2015.0   2015.0          [BN Pictures, Ajia-do]
# 12652       NaN        NaN      NaN                             NaN
# 12653       NaN        NaN      NaN                  [Pierrot Plus]
# 12654       4.0     2014.0   2014.0                [Pie in the sky]
# 12655       NaN     2014.0   2014.0                [Pie in the sky]
# 12656      50.0     2014.0   2014.0                [Shirogumi Inc.]
# 12657       NaN     2014.0   2014.0             [The Answer Studio]
# 12658       5.0     2014.0   2015.0                           [DLE]
# 12659       6.0     2013.0   2014.0                           [DLE]
# 12660       NaN     2013.0   2013.0  [Nippon Animation, Graphinica]
# 12661       NaN     2022.0   2022.0                         [Gaina]
# 12662       NaN     2014.0   2014.0                        [Sanrio]
# 12663       NaN     1991.0   1991.0                             NaN
# 12664       5.0     2006.0   2008.0                             NaN
# 12665       NaN        NaN      NaN   [Studio A-Cat, "Brains Base"]
# 12666      35.0     2010.0   2010.0                             NaN
# 12667       NaN     2015.0   2015.0                           [DLE]
# 12668       NaN     2014.0   2014.0                     [Wao World]
# 12669       NaN     2005.0   2006.0                         [IMOVE]
# 12670       NaN        NaN      NaN                             NaN
# 12671       NaN        NaN      NaN                             NaN
# 12672      10.0     2014.0   2014.0                   [Studio Deen]
# 12673       NaN        NaN      NaN                             NaN
# 12674       NaN     2013.0   2013.0                             NaN
# 12675      15.0     2012.0   2013.0                             NaN
# 12676       NaN     2015.0      NaN                         [Shaft]
# 12677       NaN        NaN      NaN                      [ufotable]
# 12678       NaN        NaN      NaN               [Mappa, MADHOUSE]
# 12679       NaN     2019.0   2019.0                             NaN
# 12680       NaN     2020.0   2020.0                  [Studio Khara]
#
#                                                     Tags  \
# 0      [Action, Adventure, Drama, Fantasy, Mystery, S...
# 1      [Drama, Romance, Body Swapping, Opposites Attr...
# 2      [Drama, Melancholy, School Life, Bullying, Mat...
# 3      [Shounen, Sports, Animeism, School Club, Schoo...
# 4      [Action, Comedy, Drama, Sci Fi, Shounen, Super...
# 5      [Action, Comedy, Shounen, Psychic Powers, Psyc...
# 6      [Shounen, Sports, School Club, School Life, To...
# 7      [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 8      [Action, Comedy, Drama, Sci Fi, Shounen, Schoo...
# 9      [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 10     [Sci Fi, Conspiracy, LGBT Themes, Psychologica...
# 11     [Action, Adventure, Drama, Fantasy, Shounen, M...
# 12     [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 13     [Fantasy, Horror, Mystery, Sci Fi, Shounen, Is...
# 14     [Mecha, Sci Fi, Conspiracy, Mind Games, Overpo...
# 15     [Drama, Seinen, Slice of Life, Board Games, Me...
# 16     [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 17     [Fantasy, Seinen, Episodic, Iyashikei, Superna...
# 18     [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 19     [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 20     [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 21     [Action, Comedy, Sci Fi, Seinen, Cyborgs, Mons...
# 22     [Drama, Romance, Coming of Age, Family Life, B...
# 23     [Drama, Fantasy, Shoujo, Bodyguards, Cats, Cou...
# 24     [Fantasy, Seinen, Episodic, Iyashikei, Superna...
# 25     [Adventure, Fantasy, Mystery, Sci Fi, Seinen, ...
# 26     [Fantasy, Slice of Life, Animal Characteristic...
# 27     [Adventure, Fantasy, Curse, Family Friendly, J...
# 28     [Drama, Romance, Seinen, Coming of Age, Illnes...
# 29     [Action, Adventure, Drama, Fantasy, Seinen, An...
# ...                                                  ...
# 12651  [Adventure, Comedy, Animal Protagonists, Famil...
# 12652  [Military, Military School, Ocean, War, Based ...
# 12653                         [Horror, Based on a Novel]
# 12654         [Comedy, Shoujo, Shorts, Based on a Manga]
# 12655  [Shoujo, Animal Protagonists, Dogs, Based on a...
# 12656  [Comedy, Sports, Family Friendly, Soccer, Orig...
# 12657  [Adventure, Fantasy, Animal Protagonists, Fami...
# 12658  [Comedy, Short Episodes, Superheroes, Flash An...
# 12659  [Comedy, Short Episodes, Superheroes, Flash An...
# 12660                                  [Comedy, Royalty]
# 12661                            [Sci Fi, Original Work]
# 12662                                          [Fantasy]
# 12663                                                NaN
# 12664               [Horror, Historical, Short Episodes]
# 12665                [Mecha, Time Travel, Original Work]
# 12666                                                NaN
# 12667                                           [Comedy]
# 12668                       [Japanese Mythology, Youkai]
# 12669         [Comedy, Fantasy, Angels, Family Friendly]
# 12670                                                NaN
# 12671                               [Idols, Promotional]
# 12672                           [Comedy, Short Episodes]
# 12673                           [Fantasy, Original Work]
# 12674                                           [Comedy]
# 12675                                  [Family Friendly]
# 12676               [Magical Girl, Magic, Original Work]
# 12677                                          [Fantasy]
# 12678                                           [Sci Fi]
# 12679          [Action, Sci Fi, Monsters, Original Work]
# 12680                       [Mecha, Sci Fi, Super Robot]
#
#                                              Description
# 0      The foundation of alchemy is based on the law ...
# 1      Mitsuha and Taki are two total strangers livin...
# 2      After transferring into a new school, a deaf g...
# 3      Picking up where the second season ended, the ...
# 4                      Third season of My Hero Academia.
# 5                       Second Season of Mob Psycho 100.
# 6      After losing to Aoba Johsai at the Inter-High,...
# 7      While watching a movie, Gintoki comes upon a "...
# 8      In a world where eighty percent of the populat...
# 9                              Fourth season of Gintama.
# 10     The eccentric mad scientist Okabe, his childho...
# 11     Drawn to the mystique of the unknown, Hunters ...
# 12     Continuation of Gintama.: Shirogane no Tamashi...
# 13     Emma, Norman, Ray, and many other "siblings" l...
# 14     Area 11 is still under Britannian rule and the...
# 15     Rei continues to work hard at improving his sh...
# 16                              Fifth season of Gintama.
# 17                   Continuation of Mushishi Zoku Shou.
# 18                                 Final arc of Gintama.
# 19     Gintoki Sakata, Kagura, and Shinpachi Shimura ...
# 20                              Third season of Gintama.
# 21     In a city plagued with thugs, mutants, and sup...
# 22     Summer break is now over; the second semester ...
# 23     Precious days with kinds friends. A beautiful ...
# 24     They existed long before anyone can remember. ...
# 25     Young Riko has spent her entire childhood drea...
# 26     Hana was a student before she was a mother. Sh...
# 27     Chihiro and her family are on their way to the...
# 28     An unnamed protagonist happens to find a diary...
# 29     Naofumi Iwatani, an uncharismatic Otaku who sp...
# ...                                                  ...
# 12651                                                NaN
# 12652                                                NaN
# 12653  The story centers around a first-year universi...
# 12654  The manga revolves around sixth grader, Matsum...
# 12655  The story revolves around a not-so-normal high...
# 12656                                                NaN
# 12657                                                NaN
# 12658       Fifth season of Himitsukessha Taka no Tsume.
# 12659      Fourth season of Himitsukessha Taka no Tsume.
# 12660  The stories follow a king who loves eating egg...
# 12661                                                NaN
# 12662                                                NaN
# 12663                                                NaN
# 12664                                                NaN
# 12665  The story of the mecha anime revolves around 1...
# 12666                                                NaN
# 12667  In this spoof, the orphan Nello and his dog Pa...
# 12668                                                NaN
# 12669  Kotenko acts as a protector of the Angel Star ...
# 12670                                                NaN
# 12671  The anime's tagline is "With the stage set for...
# 12672  Hiyori's grandmother died. To stop her crying ...
# 12673                                                NaN
# 12674  The surreal, comical television anime follow t...
# 12675  Nelvana welcomes you to Mojies Town – a magica...
# 12676  In a future not too distant from ours, "Nanago...
# 12677                                                NaN
# 12678                                                NaN
# 12679                                                NaN
# 12680                                                NaN
#
# [12681 rows x 12 columns]

# %%
df['Votes'].min()
# Out:
# 10.0

# %%
df.dtypes
# Out:
# Rating          float64
# Votes           float64
# Title            object
# Alt Title        object
# Format         category
# Episodes        float64
# Duration        float64
# Start Year     category
# End Year       category
# Studio           object
# Tags             object
# Description      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Rating         2717
# Votes          2717
# Title             0
# Alt Title      7482
# Format            0
# Episodes        387
# Duration       5342
# Start Year      187
# End Year        343
# Studio         3724
# Tags            338
# Description    5298
# dtype: int64

# %%
df['Format'].value_counts()
# Out:
# TV             4215
# Movie          2279
# OVA            1971
# Web            1129
# Music Video    1124
# DVD Special     776
# Other           646
# TV Special      541
# Name: Format, dtype: int64

# %%
# %matplotlib inline
ax = df['Format'].value_counts().plot(kind='bar')
ax.set_xlabel('Format', fontsize=12)
_ = ax.set_ylabel('Number of Pieces', fontsize=12)

# %%
bins = range(1, 11)
ax = pd.cut(list(df['Rating']), bins, right=False).value_counts().plot(kind='bar')
ax.set_xlabel('Rating', fontsize=12)
_ = ax.set_ylabel('Number of Pieces', fontsize=12)

# %%
ax = df.loc[df['Rating'] >= 7, 'Start Year'].value_counts().head(20).plot(kind='bar')
ax.set_xlabel('Year', fontsize=12)
_ = ax.set_ylabel('Number of Highly Rated Anime\n (Rating >= 7)', fontsize=12)

# %%
bins = [0, 10, 20, 30, 40, 50, 60, 70, 100, 300, 500, 1000]
ax = pd.cut(list(df.loc[(df['Format'] == 'TV') & (df['Rating'] >= 7), 'Episodes']), bins, right=False).value_counts().plot(kind='bar')
ax.set_xlabel('Number of Episodes', fontsize=12)
_ = ax.set_ylabel('Number of Good Pieces', fontsize=12)

# %%
bins = [0, 10, 20, 30, 40, 50, 60, 70, 100, 300, 500, 1000]
ax = pd.cut(list(df.loc[(df['Format'] == 'TV') & (df['Rating'] < 7), 'Episodes']), bins, right=False).value_counts().plot(kind='bar')
ax.set_xlabel('Number of Episodes', fontsize=12)
_ = ax.set_ylabel('Number of Mediocre Pieces', fontsize=12)

# %%
good = pd.cut(list(df.loc[(df['Format'] == 'TV') & (df['Rating'] >= 7), 'Episodes']), bins, right=False).value_counts()
mediocre = pd.cut(list(df.loc[(df['Format'] == 'TV') & (df['Rating'] < 7), 'Episodes']), bins, right=False).value_counts() 
ratio = [int(b) / int(m) for b,m in zip(good, mediocre)]
ax = pd.Series(ratio, index=good.index, name='Ratio').plot(kind='bar')
ax.set_xlabel('Number of Episodes', fontsize=12)
_ = ax.set_ylabel('Ratio of Good/Mediocre', fontsize=12)

# %%
df.loc[(df['Rating'] >= 7) & (df['Episodes'] >= 500) & (df['Episodes'] < 1000)]
# Out:
#       Rating    Votes             Title                             Alt Title  \
# 227    8.796  53167.0         One Piece                                   NaN
# 579    8.472  67836.0  Naruto Shippuden                                   NaN
# 974    8.198  13599.0   Detective Conan          Case Closed, Meitantei Conan
# 2279   7.446    464.0   Doraemon (2005)  Doraemon: Gadget Cat from the Future
# 2896   7.130   5416.0  Crayon Shin-chan                                   NaN
#
#      Format  Episodes  Duration Start Year End Year  \
# 227      TV     878.0       NaN     1999.0      NaN
# 579      TV     500.0       NaN     2007.0   2017.0
# 974      TV     935.0       NaN     1996.0      NaN
# 2279     TV     553.0       NaN     2005.0      NaN
# 2896     TV     992.0       NaN     1992.0      NaN
#
#                               Studio  \
# 227                 [Toei Animation]
# 579                 [Studio Pierrot]
# 974   [TMS Entertainment, V1 Studio]
# 2279             [Shin-Ei Animation]
# 2896             [Shin-Ei Animation]
#
#                                                    Tags  \
# 227   [Action, Adventure, Comedy, Fantasy, Shounen, ...
# 579   [Action, Drama, Fantasy, Shounen, Hand to Hand...
# 974   [Drama, Mystery, Shounen, Age Transformation, ...
# 2279  [Adventure, Comedy, Shounen, Cats, Family Frie...
# 2896  [Comedy, Ecchi, Slice of Life, Crude, Mature T...
#
#                                             Description
# 227   Long ago the infamous Gol D. Roger was the str...
# 579   Two and a half years have passed since the end...
# 974   Shinichi Kudo is a famous teenage detective wh...
# 2279  Robotic cat Doraemon is sent back in time from...
# 2896  Shinnosuke Nohara is a crude and rude five-yea...

# %%
def contains (col, elems):
    booleans = []
    for tags in df[col]:
        exists = True
        for item in elems:
            if type(tags) == float:
                exists = False
            elif item not in tags:
                exists = False
        if type(tags) == float:
            booleans.append(False)                   
        elif exists:
            booleans.append(True)
        else:
            booleans.append(False)
    return booleans

# %%
df.loc[np.array(contains('Tags', ['Action','Adventure','Fantasy', 'Magic', 'Shounen', 'Comedy']))]
# Out:
#       Rating    Votes                                              Title  \
# 41     9.102   8531.0            That Time I Got Reincarnated as a Slime
# 83     9.010   3773.0                                  Fairy Tail (2018)
# 129    8.914  17897.0                         Magi: The Kingdom of Magic
# 202    8.820  22358.0                                       Fairy Tail 2
# 266    8.756   7034.0                          Magi: Adventure of Sinbad
# 368    8.664   4202.0                      Magi: Adventure of Sinbad OVA
# 378    8.656  60085.0                                         Fairy Tail
# 392    8.642  23697.0                       Magi: The Labyrinth of Magic
# 5515   5.822    691.0  That Time I Got Reincarnated as a Slime: Veldo...
#
#                                               Alt Title      Format  Episodes  \
# 41                       Tensei Shitara Slime Datta Ken          TV      24.0
# 83                                                  NaN          TV      25.0
# 129                                                 NaN          TV      25.0
# 202                                                 NaN          TV     102.0
# 266                              Magi: Sinbad no Bouken          TV      13.0
# 368                          Magi: Sinbad no Bouken OVA         OVA       5.0
# 378                                                 NaN          TV     175.0
# 392                                                 NaN          TV      25.0
# 5515  Tensei Shitara Slime Datta Ken: Kanwa "Veldora...  TV Special       1.0
#
#       Duration Start Year End Year                               Studio  \
# 41         NaN     2018.0   2019.0                              [8-Bit]
# 83         NaN     2018.0      NaN  [Bridge, A-1 Pictures, CloverWorks]
# 129        NaN     2013.0   2014.0                       [A-1 Pictures]
# 202        NaN     2014.0   2016.0               [Bridge, A-1 Pictures]
# 266        NaN     2016.0   2016.0                           [Lay-duce]
# 368        NaN     2014.0   2015.0                           [Lay-duce]
# 378        NaN     2009.0   2013.0            [Satelight, A-1 Pictures]
# 392        NaN     2012.0   2013.0                       [A-1 Pictures]
# 5515       NaN     2019.0   2019.0                              [8-Bit]
#
#                                                    Tags  \
# 41    [Action, Adventure, Comedy, Fantasy, Shounen, ...
# 83    [Action, Adventure, Comedy, Fantasy, Shounen, ...
# 129   [Action, Adventure, Comedy, Fantasy, Shounen, ...
# 202   [Action, Adventure, Comedy, Fantasy, Shounen, ...
# 266   [Action, Adventure, Comedy, Fantasy, Shounen, ...
# 368   [Action, Adventure, Comedy, Fantasy, Shounen, ...
# 378   [Action, Adventure, Comedy, Drama, Fantasy, Sh...
# 392   [Action, Adventure, Comedy, Fantasy, Shounen, ...
# 5515  [Action, Adventure, Comedy, Fantasy, Shounen, ...
#
#                                             Description
# 41    Lonely thirty-seven-year-old Satoru Mikami is ...
# 83                      The final season of Fairy Tail.
# 129   Equipped with a charm to mask his powers as a ...
# 202   Natsu, Lucy, and their fellow Fairy Tail mages...
# 266   Thirty years before the events of Magi, a brav...
# 368   The story takes place 30 years before the even...
# 378   Lucy is a seventeen-year-old mage with the pow...
# 392   In a sand-swept land of caravans, brigands and...
# 5515  Ifrit and Veldora recap Rimuru's journey as th...

# %%
df.loc[(np.array(contains('Studio', ['Bones']))) & (np.array(contains('Tags', ['Drama']))) & (df['Rating'] >= 9)]
# Out:
#     Rating    Votes                             Title  \
# 0    9.410  73986.0  Fullmetal Alchemist: Brotherhood
# 4    9.296  18788.0                My Hero Academia 3
# 8    9.264  29623.0                My Hero Academia 2
# 70   9.046  36568.0                  My Hero Academia
#
#                                          Alt Title Format  Episodes  Duration  \
# 0   Hagane no Renkinjutsushi: Full Metal Alchemist     TV      64.0       NaN
# 4                          Boku no Hero Academia 3     TV      25.0       NaN
# 8                          Boku no Hero Academia 2     TV      25.0       NaN
# 70                           Boku no Hero Academia     TV      13.0       NaN
#
#    Start Year End Year   Studio  \
# 0      2009.0   2010.0  [Bones]
# 4      2018.0   2018.0  [Bones]
# 8      2017.0   2017.0  [Bones]
# 70     2016.0   2016.0  [Bones]
#
#                                                  Tags  \
# 0   [Action, Adventure, Drama, Fantasy, Mystery, S...
# 4   [Action, Comedy, Drama, Sci Fi, Shounen, Super...
# 8   [Action, Comedy, Drama, Sci Fi, Shounen, Schoo...
# 70  [Action, Comedy, Drama, Sci Fi, Shounen, Schoo...
#
#                                           Description
# 0   The foundation of alchemy is based on the law ...
# 4                   Third season of My Hero Academia.
# 8   In a world where eighty percent of the populat...
# 70  Izuku has dreamt of being a hero all his life—...

# %%
df.groupby('Format')['Rating'].mean()
# Out:
# Format
# DVD Special    6.177924
# Movie          6.189008
# Music Video    4.661024
# OVA            6.049877
# Other          5.227216
# TV             6.476866
# TV Special     6.318064
# Web            5.093503
# Name: Rating, dtype: float64

# %%
df.groupby('Format')['Rating'].median()
# Out:
# Format
# DVD Special    6.174
# Movie          6.386
# Music Video    4.436
# OVA            6.038
# Other          5.128
# TV             6.564
# TV Special     6.436
# Web            4.916
# Name: Rating, dtype: float64

# %%
def ratingGroupSplitter(df, ind):
    if df.loc[ind, 'Rating'] == np.NaN:
        return 'Null'
    elif df.loc[ind, 'Rating'] >= 7:
        return 'Good'
    else:
        return 'Mediocre'

df.groupby(lambda x: ratingGroupSplitter(df, x))['Title'].count()
# Out:
# Good        3153
# Mediocre    9528
# Name: Title, dtype: int64

# %% [markdown]
# #### Plot relationship between movie duration and rating

# %%
df
# Out:
#        Rating    Votes                                              Title  \
# 0       9.410  73986.0                   Fullmetal Alchemist: Brotherhood
# 1       9.356  29247.0                                         your name.
# 2       9.334  19592.0                                     A Silent Voice
# 3       9.320  11195.0  Haikyuu!! Karasuno High School vs Shiratorizaw...
# 4       9.296  18788.0                                 My Hero Academia 3
# 5       9.288   2939.0                                  Mob Psycho 100 II
# 6       9.274  15322.0                            Haikyuu!! Second Season
# 7       9.266   5375.0        Gintama Kanketsu-hen: Yorozuya yo Eien Nare
# 8       9.264  29623.0                                 My Hero Academia 2
# 9       9.262   6192.0                                     Gintama (2015)
# 10      9.256  42599.0                                        Steins;Gate
# 11      9.256  35732.0                             Hunter x Hunter (2011)
# 12      9.248   1248.0              Gintama.: Shirogane no Tamashii-hen 2
# 13      9.246   4144.0                             The Promised Neverland
# 14      9.240  59301.0            Code Geass: Lelouch of the Rebellion R2
# 15      9.228   2430.0              March Comes in like a Lion 2nd Season
# 16      9.222   3497.0                                           Gintama.
# 17      9.218   5109.0                      Mushishi Zoku Shou 2nd Season
# 18      9.210   1803.0                Gintama.: Shirogane no Tamashii-hen
# 19      9.200   9542.0                                           Gintama'
# 20      9.198   7238.0                                Gintama': Enchousen
# 21      9.196  48807.0                                      One-Punch Man
# 22      9.196  38709.0                                Clannad After Story
# 23      9.192   2718.0                            Natsume Yuujinchou Roku
# 24      9.184   6015.0                                 Mushishi Zoku Shou
# 25      9.178  10098.0                                      Made in Abyss
# 26      9.176  21464.0                                      Wolf Children
# 27      9.164  71965.0                                      Spirited Away
# 28      9.162   1359.0                        I Want to Eat Your Pancreas
# 29      9.158   5336.0                      The Rising of the Shield Hero
# ...       ...      ...                                                ...
# 12651     NaN      NaN     Kaiketsu Zorori Movie 3: Uchuu no Yuusha-tachi
# 12652     NaN      NaN                     Kantai Collection: Kan Colle 2
# 12653     NaN      NaN                                     Shishou Series
# 12654     NaN      NaN                                    Kaseifu ga Ita.
# 12655     NaN      NaN                                          Inui-san!
# 12656     NaN      NaN                             Yuuto-kun ga Iku Movie
# 12657     NaN      NaN                        Shimajirou to Kujira no Uta
# 12658     NaN      NaN                     Himitsukessha Taka no Tsume EX
# 12659     NaN      NaN                    Himitsukessha Taka no Tsume MAX
# 12660     NaN      NaN                                    Boku wa Ou-sama
# 12661     NaN      NaN                                           Aoki Uru
# 12662     NaN      NaN                          Kurumiwari Ningyou (2014)
# 12663     NaN      NaN                            Ticonderonga no Iru Umi
# 12664     NaN      NaN                                          Ehon Yose
# 12665     NaN      NaN                              Choujikuu Robo Meguru
# 12666     NaN      NaN                                     Mecha Afro-kun
# 12667     NaN      NaN          Tensai Bakavon: Yomigaeru Flanders no Inu
# 12668     NaN      NaN                Spo-chan Taiketsu: Youkai Daikessen
# 12669     NaN      NaN                                       Kotenkotenko
# 12670     NaN      NaN                                        Project 758
# 12671     NaN      NaN                                         Tsubu★Doll
# 12672     NaN      NaN                                            Washimo
# 12673     NaN      NaN                                               Mint
# 12674     NaN      NaN                                   Odoriko Clinoppe
# 12675     NaN      NaN                                     Paboo & Mojies
# 12676     NaN      NaN                           Magical Suite Prism Nana
# 12677     NaN      NaN                                        Girls' Work
# 12678     NaN      NaN                                    Yume Miru Kikai
# 12679     NaN      NaN                                        Cencoroll 2
# 12680     NaN      NaN                       Rebuild of Evangelion: Final
#
#                                                Alt Title Format  Episodes  \
# 0         Hagane no Renkinjutsushi: Full Metal Alchemist     TV      64.0
# 1                                         Kimi no Na wa.  Movie       1.0
# 2                                         Koe no Katachi  Movie       1.0
# 3       Haikyuu!! 3rd Season: Karasuno High vs. Shira...     TV      10.0
# 4                                Boku no Hero Academia 3     TV      25.0
# 5                                                    NaN     TV      12.0
# 6                                                    NaN     TV      25.0
# 7      Gintama The Movie: The Final Chapter - Be Fore...  Movie       1.0
# 8                                Boku no Hero Academia 2     TV      25.0
# 9                                               Gintama°     TV      51.0
# 10                                                   NaN     TV      24.0
# 11                                                   NaN     TV     148.0
# 12                            Gintama: Silver Soul Arc 2     TV      14.0
# 13                                 Yakusoku no Neverland     TV      12.0
# 14                    Code Geass: Hangyaku no Lelouch R2     TV      25.0
# 15                            3-gatsu no Lion 2nd Season     TV      22.0
# 16                                                   NaN     TV      12.0
# 17                    Mushishi -Next Passage- 2nd Season     TV      10.0
# 18                              Gintama: Silver Soul Arc     TV      12.0
# 19                                       Gintama' (2011)     TV      51.0
# 20                                                   NaN     TV      13.0
# 21                                                   NaN     TV      12.0
# 22                                                   NaN     TV      24.0
# 23                    Natsume's Book of Friends Season 6     TV      11.0
# 24                               Mushishi -Next Passage-     TV      10.0
# 25                                                   NaN     TV      13.0
# 26                          Ookami Kodomo no Ame to Yuki  Movie       1.0
# 27                         Sen to Chihiro no Kamikakushi  Movie       1.0
# 28                             Kimi no Suizou wo Tabetai  Movie       1.0
# 29                           Tate no Yuusha no Nariagari     TV      12.0
# ...                                                  ...    ...       ...
# 12651                                                NaN  Movie       1.0
# 12652                                                NaN     TV       NaN
# 12653                                                NaN     TV       NaN
# 12654                                                NaN    OVA       1.0
# 12655                                                NaN    OVA       2.0
# 12656                        Gekijouban Yuuto-kun ga Iku  Movie       1.0
# 12657                                                NaN  Movie       1.0
# 12658                                     Eagle Talon EX     TV      38.0
# 12659                                    Eagle Talon MAX     TV      38.0
# 12660                                                NaN     TV      12.0
# 12661                                        Uru in Blue  Movie       NaN
# 12662                          Nutcracker Fantasy (2014)  Movie       1.0
# 12663                                                NaN    OVA       1.0
# 12664                                                NaN     TV      50.0
# 12665                         Hyperdimension Robo Meguru  Other       NaN
# 12666                    Cyborg Salaryman Mecha Afro-kun    OVA       1.0
# 12667                                                NaN  Movie       1.0
# 12668                                                NaN  Movie       1.0
# 12669                                                NaN     TV      52.0
# 12670                                                NaN  Other       NaN
# 12671                                                NaN    OVA       NaN
# 12672                                                NaN     TV      10.0
# 12673                                                NaN  Movie       NaN
# 12674                                                NaN     TV      26.0
# 12675                                                NaN     TV      52.0
# 12676                                                NaN    OVA       2.0
# 12677                                                NaN  Other       NaN
# 12678                                  The Dream Machine  Movie       NaN
# 12679                                                NaN  Movie       NaN
# 12680   Shin Evangelion Gekijou-ban :||, Shin Evangel...  Movie       NaN
#
#        Duration Start Year End Year                          Studio  \
# 0           NaN     2009.0   2010.0                         [Bones]
# 1         107.0     2016.0   2016.0               [CoMix Wave Inc.]
# 2         130.0     2016.0   2016.0               [Kyoto Animation]
# 3           NaN     2016.0   2016.0                [Production I.G]
# 4           NaN     2018.0   2018.0                         [Bones]
# 5           NaN     2019.0      NaN                         [Bones]
# 6           NaN     2015.0   2016.0                [Production I.G]
# 7         111.0     2013.0   2013.0                       [Sunrise]
# 8           NaN     2017.0   2017.0                         [Bones]
# 9           NaN     2015.0   2016.0                   [BN Pictures]
# 10          NaN     2011.0   2011.0                     [WHITE FOX]
# 11          NaN     2011.0   2014.0                      [MADHOUSE]
# 12          NaN     2018.0   2018.0                   [BN Pictures]
# 13          NaN     2019.0   2019.0                   [CloverWorks]
# 14          NaN     2008.0   2008.0                       [Sunrise]
# 15          NaN     2017.0   2018.0                         [Shaft]
# 16          NaN     2017.0   2017.0                   [BN Pictures]
# 17          NaN     2014.0   2014.0                       [Artland]
# 18          NaN     2018.0   2018.0                   [BN Pictures]
# 19          NaN     2011.0   2012.0                       [Sunrise]
# 20          NaN     2012.0   2013.0                       [Sunrise]
# 21          NaN     2015.0   2015.0                      [MADHOUSE]
# 22          NaN     2008.0   2009.0               [Kyoto Animation]
# 23          NaN     2017.0   2017.0                         [Shuka]
# 24          NaN     2014.0   2014.0                       [Artland]
# 25          NaN     2017.0   2017.0                 [Kinema Citrus]
# 26        117.0     2012.0   2012.0                  [Studio Chizu]
# 27        125.0     2001.0   2001.0                 [Studio Ghibli]
# 28        120.0     2018.0   2018.0                   [Studio VOLN]
# 29          NaN     2019.0      NaN                 [Kinema Citrus]
# ...         ...        ...      ...                             ...
# 12651      49.0     2015.0   2015.0          [BN Pictures, Ajia-do]
# 12652       NaN        NaN      NaN                             NaN
# 12653       NaN        NaN      NaN                  [Pierrot Plus]
# 12654       4.0     2014.0   2014.0                [Pie in the sky]
# 12655       NaN     2014.0   2014.0                [Pie in the sky]
# 12656      50.0     2014.0   2014.0                [Shirogumi Inc.]
# 12657       NaN     2014.0   2014.0             [The Answer Studio]
# 12658       5.0     2014.0   2015.0                           [DLE]
# 12659       6.0     2013.0   2014.0                           [DLE]
# 12660       NaN     2013.0   2013.0  [Nippon Animation, Graphinica]
# 12661       NaN     2022.0   2022.0                         [Gaina]
# 12662       NaN     2014.0   2014.0                        [Sanrio]
# 12663       NaN     1991.0   1991.0                             NaN
# 12664       5.0     2006.0   2008.0                             NaN
# 12665       NaN        NaN      NaN   [Studio A-Cat, "Brains Base"]
# 12666      35.0     2010.0   2010.0                             NaN
# 12667       NaN     2015.0   2015.0                           [DLE]
# 12668       NaN     2014.0   2014.0                     [Wao World]
# 12669       NaN     2005.0   2006.0                         [IMOVE]
# 12670       NaN        NaN      NaN                             NaN
# 12671       NaN        NaN      NaN                             NaN
# 12672      10.0     2014.0   2014.0                   [Studio Deen]
# 12673       NaN        NaN      NaN                             NaN
# 12674       NaN     2013.0   2013.0                             NaN
# 12675      15.0     2012.0   2013.0                             NaN
# 12676       NaN     2015.0      NaN                         [Shaft]
# 12677       NaN        NaN      NaN                      [ufotable]
# 12678       NaN        NaN      NaN               [Mappa, MADHOUSE]
# 12679       NaN     2019.0   2019.0                             NaN
# 12680       NaN     2020.0   2020.0                  [Studio Khara]
#
#                                                     Tags  \
# 0      [Action, Adventure, Drama, Fantasy, Mystery, S...
# 1      [Drama, Romance, Body Swapping, Opposites Attr...
# 2      [Drama, Melancholy, School Life, Bullying, Mat...
# 3      [Shounen, Sports, Animeism, School Club, Schoo...
# 4      [Action, Comedy, Drama, Sci Fi, Shounen, Super...
# 5      [Action, Comedy, Shounen,  Psychic Powers, Psy...
# 6      [Shounen, Sports, School Club, School Life, To...
# 7      [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 8      [Action, Comedy, Drama, Sci Fi, Shounen, Schoo...
# 9      [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 10     [Sci Fi, Conspiracy, LGBT Themes, Psychologica...
# 11     [Action, Adventure, Drama, Fantasy, Shounen, M...
# 12     [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 13     [Fantasy, Horror, Mystery, Sci Fi, Shounen, Is...
# 14     [Mecha, Sci Fi, Conspiracy, Mind Games, Overpo...
# 15     [Drama, Seinen, Slice of Life, Board Games, Me...
# 16     [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 17     [Fantasy, Seinen, Episodic, Iyashikei, Superna...
# 18     [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 19     [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 20     [Action, Comedy, Drama, Sci Fi, Shounen, Alien...
# 21     [Action, Comedy, Sci Fi, Seinen, Cyborgs, Mons...
# 22     [Drama, Romance, Coming of Age, Family Life, B...
# 23     [Drama, Fantasy, Shoujo, Bodyguards, Cats, Cou...
# 24     [Fantasy, Seinen, Episodic, Iyashikei, Superna...
# 25     [Adventure, Fantasy, Mystery, Sci Fi, Seinen, ...
# 26     [Fantasy, Slice of Life, Animal Characteristic...
# 27     [Adventure, Fantasy, Curse, Family Friendly, J...
# 28     [Drama, Romance, Seinen, Coming of Age, Illnes...
# 29     [Action, Adventure, Drama, Fantasy, Seinen, An...
# ...                                                  ...
# 12651  [Adventure, Comedy, Animal Protagonists, Famil...
# 12652  [Military, Military School, Ocean, War, Based ...
# 12653                         [Horror, Based on a Novel]
# 12654         [Comedy, Shoujo, Shorts, Based on a Manga]
# 12655  [Shoujo, Animal Protagonists, Dogs, Based on a...
# 12656  [Comedy, Sports, Family Friendly, Soccer, Orig...
# 12657  [Adventure, Fantasy, Animal Protagonists, Fami...
# 12658  [Comedy, Short Episodes, Superheroes, Flash An...
# 12659  [Comedy, Short Episodes, Superheroes, Flash An...
# 12660                                  [Comedy, Royalty]
# 12661                            [Sci Fi, Original Work]
# 12662                                          [Fantasy]
# 12663                                                NaN
# 12664               [Horror, Historical, Short Episodes]
# 12665                [Mecha, Time Travel, Original Work]
# 12666                                                NaN
# 12667                                           [Comedy]
# 12668                       [Japanese Mythology, Youkai]
# 12669         [Comedy, Fantasy, Angels, Family Friendly]
# 12670                                                NaN
# 12671                               [Idols, Promotional]
# 12672                           [Comedy, Short Episodes]
# 12673                           [Fantasy, Original Work]
# 12674                                           [Comedy]
# 12675                                  [Family Friendly]
# 12676               [Magical Girl, Magic, Original Work]
# 12677                                          [Fantasy]
# 12678                                           [Sci Fi]
# 12679          [Action, Sci Fi, Monsters, Original Work]
# 12680                       [Mecha, Sci Fi, Super Robot]
#
#                                              Description
# 0      The foundation of alchemy is based on the law ...
# 1      Mitsuha and Taki are two total strangers livin...
# 2      After transferring into a new school, a deaf g...
# 3      Picking up where the second season ended, the ...
# 4                      Third season of My Hero Academia.
# 5                       Second Season of Mob Psycho 100.
# 6      After losing to Aoba Johsai at the Inter-High,...
# 7      While watching a movie, Gintoki comes upon a "...
# 8      In a world where eighty percent of the populat...
# 9                              Fourth season of Gintama.
# 10     The eccentric mad scientist Okabe, his childho...
# 11     Drawn to the mystique of the unknown, Hunters ...
# 12     Continuation of Gintama.: Shirogane no Tamashi...
# 13     Emma, Norman, Ray, and many other "siblings" l...
# 14     Area 11 is still under Britannian rule and the...
# 15     Rei continues to work hard at improving his sh...
# 16                              Fifth season of Gintama.
# 17                   Continuation of Mushishi Zoku Shou.
# 18                                 Final arc of Gintama.
# 19     Gintoki Sakata, Kagura, and Shinpachi Shimura ...
# 20                              Third season of Gintama.
# 21     In a city plagued with thugs, mutants, and sup...
# 22     Summer break is now over; the second semester ...
# 23     Precious days with kinds friends. A beautiful ...
# 24     They existed long before anyone can remember. ...
# 25     Young Riko has spent her entire childhood drea...
# 26     Hana was a student before she was a mother. Sh...
# 27     Chihiro and her family are on their way to the...
# 28     An unnamed protagonist happens to find a diary...
# 29     Naofumi Iwatani, an uncharismatic Otaku who sp...
# ...                                                  ...
# 12651                                                NaN
# 12652                                                NaN
# 12653  The story centers around a first-year universi...
# 12654  The manga revolves around sixth grader, Matsum...
# 12655  The story revolves around a not-so-normal high...
# 12656                                                NaN
# 12657                                                NaN
# 12658       Fifth season of Himitsukessha Taka no Tsume.
# 12659      Fourth season of Himitsukessha Taka no Tsume.
# 12660  The stories follow a king who loves eating egg...
# 12661                                                NaN
# 12662                                                NaN
# 12663                                                NaN
# 12664                                                NaN
# 12665  The story of the mecha anime revolves around 1...
# 12666                                                NaN
# 12667  In this spoof, the orphan Nello and his dog Pa...
# 12668                                                NaN
# 12669  Kotenko acts as a protector of the Angel Star ...
# 12670                                                NaN
# 12671  The anime's tagline is "With the stage set for...
# 12672  Hiyori's grandmother died. To stop her crying ...
# 12673                                                NaN
# 12674  The surreal, comical television anime follow t...
# 12675  Nelvana welcomes you to Mojies Town – a magica...
# 12676  In a future not too distant from ours, "Nanago...
# 12677                                                NaN
# 12678                                                NaN
# 12679                                                NaN
# 12680                                                NaN
#
# [12681 rows x 12 columns]

# %%
df.corr()
# Out:
#             Rating     Votes  Episodes  Duration
# Rating    1.000000  0.404422  0.043744  0.474435
# Votes     0.404422  1.000000  0.082555  0.310673
# Episodes  0.043744  0.082555  1.000000 -0.064012
# Duration  0.474435  0.310673 -0.064012  1.000000

# %%
df.loc[df['Format'] == 'Movie'].corr()
# Out:
#             Rating     Votes  Episodes  Duration
# Rating    1.000000  0.368592       NaN  0.674744
# Votes     0.368592  1.000000       NaN  0.292181
# Episodes       NaN       NaN       NaN       NaN
# Duration  0.674744  0.292181       NaN  1.000000

# %% [markdown]
# #### Strong correlation!!

# %%
plt.scatter(df.loc[df['Format'] == 'Movie', 'Duration'], df.loc[df['Format'] == 'Movie', 'Rating'])
m = df.loc[df['Format'] == 'Movie', 'Duration'].corr(df.loc[df['Format'] == 'Movie', 'Rating'])

linear_regressor = LinearRegression()  # create object for the class
mean_dur = df.loc[df['Format'] == 'Movie', 'Duration'].mean()
mean_rat = df.loc[df['Format'] == 'Movie', 'Rating'].mean()
linear_regressor.fit(df.loc[df['Format'] == 'Movie', 'Duration'].fillna(value=mean_dur).values.reshape(-1, 1), df.loc[df['Format'] == 'Movie', 'Rating'].fillna(value=mean_rat).values.reshape(-1, 1))  # perform linear regression
Y_pred = linear_regressor.predict(df.loc[df['Format'] == 'Movie', 'Duration'].fillna(value=mean_dur).values.reshape(-1, 1))  # make predictions

plt.plot(df.loc[df['Format'] == 'Movie', 'Duration'].fillna(value=mean_dur).values.reshape(-1, 1), Y_pred, color='red')
plt.xlim(-0.5, 170)
plt.ylim(1.5, 9.6)
plt.xlabel('Duration (min)', fontsize=12)
plt.ylabel('Rating', fontsize=12)
print(m)
# Out:
# 0.6747436971220776

# %%
def labelsFromBins(bins, left='[', sep=',', right=')'):
    labels = []
    for i in range(len(bins) - 1):
        label = left + str(bins[i]) + sep + str(bins[i + 1]) + right
        labels.append(label)
    return labels

# %%
def durSplitter(df, ind):
    if df.loc[ind, 'Duration'] == np.NaN:
        return 'Null'
    for i in range(0, 180, 20):
        if df.loc[ind, 'Duration'] >= i and df.loc[ind, 'Duration'] < (i + 20):
            return '[' + str(i) + ',' + str(i + 20) + ')'


ax = df.loc[df['Format'] == 'Movie'].groupby(lambda x: durSplitter(df, x))['Rating'].mean().sort_values().plot(kind='bar')
ax.set_xlabel('Duration (min)', fontsize=12)
ax.set_ylabel('Mean Rating', fontsize=12)
_ = ax.set_xticklabels(labelsFromBins(bins))

# %%
bins = [0, 10, 20, 30, 40, 50, 60, 70, 100, 300, 500, 1000]
def epsSplitter(df, ind):
    if df.loc[ind, 'Episodes'] == np.NaN:
        return 'Null'
    for i in range(len(bins) - 1):
        if df.loc[ind, 'Episodes'] >= bins[i] and df.loc[ind, 'Episodes'] < bins[i + 1]:
            return bins[i + 1]

ax = df.loc[df['Format'] == 'TV'].groupby(lambda x: epsSplitter(df, x))['Rating'].mean().plot(kind='bar')
ax.set_xlabel('Number of Episodes', fontsize=12)
ax.set_ylabel('Mean Rating', fontsize=12)
_ = ax.set_xticklabels(labelsFromBins(bins))

# %% [markdown]
# ### Find relationship between tags and rating

# %%
def listTags(tag_col):
    uniq_tags = []
    for tag_row in tag_col:
        if type(tag_row) != float:
            for each in tag_row:
                if each not in uniq_tags:
                    uniq_tags.append(each)
    return uniq_tags

# %%
tags = listTags(df['Tags'])

# %%
tags
# Out:
# ['Action',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Mystery',
#  'Shounen',
#  'Conspiracy',
#  'Military',
#  'Siblings',
#  'Violence',
#  'Animal Abuse',
#  'Based on a Manga',
#  'Romance',
#  'Body Swapping',
#  'Opposites Attract',
#  'School Life',
#  'Supernatural',
#  'Original Work',
#  'Melancholy',
#  'Bullying',
#  'Mature Themes',
#  'Suicide',
#  'Sports',
#  'Animeism',
#  'School Club',
#  'Tournaments',
#  'Volleyball',
#  'Comedy',
#  'Sci Fi',
#  'Superheroes',
#  'Superpowers',
#  'Psychic Powers',
#  'Psychological',
#  'Aliens',
#  'Feudal Japan',
#  'Samurai',
#  'Swordplay',
#  'Time Travel',
#  'Weak to Strong',
#  'Breaking the Fourth Wall',
#  'Crude',
#  'Gag',
#  'Parody',
#  'Slapstick',
#  'LGBT Themes',
#  'Thriller',
#  'Based on a Visual Novel',
#  'Monsters',
#  'Horror',
#  'Isolated Society',
#  'Mind Games',
#  'noitaminA',
#  'Orphans',
#  'Outside World',
#  'Mecha',
#  'Overpowered Main Characters',
#  'Political',
#  'Real Robot',
#  'Rebellions',
#  'Rivalries',
#  'Royalty',
#  'Terrorism',
#  'Seinen',
#  'Slice of Life',
#  'Board Games',
#  'Episodic',
#  'Iyashikei',
#  'Cyborgs',
#  'Satire',
#  'Explicit Violence',
#  'Coming of Age',
#  'Family Life',
#  'Shoujo',
#  'Bodyguards',
#  'Cats',
#  'Countryside',
#  'Japanese Mythology',
#  'Youkai',
#  'Androids',
#  'Curse',
#  'Robots',
#  'Animal Characteristics',
#  'Childcare',
#  'Contemporary Fantasy',
#  'Lifestyle Change',
#  'Single Parent',
#  'Werewolves',
#  'Family Friendly',
#  'Magic',
#  'Person in a Strange World',
#  'Illness',
#  'Based on a Novel',
#  'Dark Fantasy',
#  'Demons',
#  'RPG',
#  'Summoned Into Another World',
#  'Based on a Light Novel',
#  'Ecchi',
#  'Vampires',
#  'Nudity',
#  'Boxing',
#  'Hand to Hand Combat',
#  'Revenge',
#  'Josei',
#  'Adult Couples',
#  'Apprenticeship',
#  'Historical',
#  'Cheats',
#  'Reincarnation',
#  'Environmental',
#  'Forest',
#  'Sexual Content',
#  'War',
#  'Physical Abuse',
#  'Age Transformation',
#  'Serial Killers',
#  '19th Century',
#  'Star-Crossed Lovers',
#  'Assassins',
#  'Teaching',
#  'Proxy Battles',
#  'Urban Fantasy',
#  'Chinese Animation',
#  'Xianxia',
#  'Zombies',
#  'Classical Music',
#  'Music',
#  'Unrequited Love',
#  'Loneliness',
#  'Basketball',
#  'Bounty Hunters',
#  'Drug Use',
#  'Noir',
#  'Western',
#  'Delinquents',
#  'Work Life',
#  'Emotional Abuse',
#  'Cooking',
#  'Culinary School',
#  'Food and Beverage',
#  'Master-Servant Relationship',
#  'High Stakes Games',
#  'Anime Industry',
#  'Manga Industry',
#  'Otaku Culture',
#  'Voice Acting',
#  'Writers',
#  'Outer Space',
#  'Space Opera',
#  'Boarding House',
#  'Neighbors',
#  'MMORPG',
#  'Body Sharing',
#  'Guilds',
#  'Post-apocalyptic',
#  'Cannibalism',
#  'Criminals',
#  'Detectives',
#  'Psychopaths',
#  'Shinigami',
#  'Vigilantes',
#  'Baseball',
#  'Medieval',
#  'Pigs',
#  'Martial Arts',
#  'Trapped in a Video Game',
#  'Virtual Reality',
#  'Recap',
#  'Senpai-Kouhai Relationship',
#  'England',
#  'Europe',
#  'Gunfights',
#  'Religion',
#  'Explicit Sex',
#  'Sexual Abuse',
#  'Ghosts',
#  'Gods',
#  'Cyberpunk',
#  'Hacking',
#  'Monster-of-the-week',
#  'Art',
#  'Island',
#  'PVP',
#  'Butlers',
#  'Love Triangle',
#  'Childhood Friends',
#  'Combining Mecha',
#  'Super Robot',
#  'Based on an Eroge',
#  'God-Human Relationship',
#  'Mature Romance',
#  'Pirates',
#  'Gangs',
#  'Mercenaries',
#  'Magic School',
#  'Middle Eastern',
#  'Love Confession',
#  'Romantic Comedy',
#  'Tsundere',
#  'Student Council',
#  'America',
#  'Human Experimentation',
#  'Mafia',
#  'Trains',
#  'Insects',
#  'Short Episodes',
#  '15th Century',
#  'Based on a Video Game',
#  'Reverse Harem',
#  'Crossdressing',
#  'Debt',
#  'Hosts',
#  'Social Gap',
#  'Doctors',
#  'Germany',
#  'Medical',
#  'BL',
#  'Shounen-ai',
#  'All-Boys School',
#  'Social Media',
#  'Agriculture',
#  'Circus',
#  'Dystopia',
#  'Police',
#  'Ping Pong',
#  'College',
#  'Music School',
#  'Autobiographies',
#  'Poverty',
#  'World War 2',
#  'Leijiverse',
#  'Age Gap',
#  'Library',
#  'Cafe',
#  'Prison',
#  'Ice Skating',
#  'Magical Girl',
#  'Transfer Students',
#  'Dinosaurs',
#  'Amusement Park',
#  'Prophecy',
#  'Afterlife',
#  'Amnesia',
#  'CG Animation',
#  'Abstract',
#  'Acting',
#  'Idols',
#  'Showbiz',
#  'Mysterious Shop',
#  'Maids',
#  'Newly Co-ed School',
#  'Military School',
#  'Married Life',
#  'Kickboxing',
#  'Yakuza',
#  'Astronauts',
#  'Childhood Promise',
#  'Bar',
#  'Play or Die',
#  'Thieves',
#  'Shorts',
#  'France',
#  'Aging',
#  'No Dialogue',
#  'Ocean',
#  'PVE',
#  'Desert',
#  'Cars',
#  'Racing',
#  'Tennis',
#  'Christmas',
#  'Running',
#  'Boss-Employee Relationship',
#  'Coworkers',
#  'Editors',
#  'Yaoi Hand Syndrome',
#  'Dark Comedy',
#  'Hell',
#  'Fujoshi',
#  'Salaryman',
#  'Sherlock Holmes',
#  'Cycling',
#  'Androphobia',
#  'Restaurants',
#  'Based on a 4-Koma Manga',
#  'Cohabitation',
#  'Rock Music',
#  'Dragons',
#  'Harem',
#  'Monster Girls',
#  'Roommates',
#  'Motorcycles',
#  'Dancing',
#  'Apartment Life',
#  'Fashion',
#  'Video Game Industry',
#  'The Great Outdoors',
#  'Boarding School',
#  'Gambling',
#  'Dungeon',
#  'Angels',
#  'Blackmail',
#  'Art School',
#  'Swimming',
#  'Secret Identity',
#  '18th Century',
#  'Greek Mythology',
#  'Power Suits',
#  'Aviation',
#  'Biographies',
#  'Earthquake',
#  'Natural Disaster',
#  'Survival',
#  'Dogs',
#  'GL',
#  'Shoujo-ai',
#  'Track and Field',
#  'Animal Protagonists',
#  'Pets',
#  'Fated Lovers',
#  'Photography',
#  'Sanrio Characters',
#  'Collections',
#  'Anime Tamago',
#  'Billiards',
#  'Demon King',
#  'Monster School',
#  'All-Girls School',
#  'Hotels and Inns',
#  'Soccer',
#  'Italy',
#  'World Masterpiece Theater',
#  'Based on a Doujinshi',
#  'Astronomy',
#  'Crossover',
#  'Dream World',
#  'Jungle',
#  'Pandemic',
#  'Transforming Mecha',
#  'Journey to the West',
#  'Valentines Day',
#  'Ninja',
#  'Vocaloid',
#  'Chibi',
#  'Stalkers',
#  'Based on an Otome Game',
#  'Korean Animation',
#  'Ghost Hunters',
#  'Educational',
#  'Flash Animation',
#  'French Revolution',
#  'Mermaids',
#  'Buddhism',
#  'Christianity',
#  'Birds',
#  'Doujinshi Industry',
#  'Playboys',
#  'Based on a Comic Book',
#  'Space Pirates',
#  'Gender Bender',
#  'Based on an Anime',
#  'Archery',
#  'Panty Shots',
#  'Arranged Marriage',
#  'Steampunk',
#  'Deal with the Devil',
#  'Anime no Me',
#  'Recipes',
#  'Brother Complex',
#  'Rabbits',
#  'Baking',
#  'Sumo Wrestling',
#  'Wrestling',
#  'Fake Romance',
#  'Sentient Mecha',
#  'Ship',
#  'Based on a Mobile Game',
#  'Ballet Dancing',
#  'Kidnapping',
#  'Football',
#  'Norse Mythology',
#  'Based on a Card Game',
#  'Heaven',
#  'Card Battles',
#  'Alice in Wonderland',
#  'Prostitution',
#  'Black and White',
#  'Based on a TV Series',
#  'Student-Teacher Relationship',
#  'Mahjong',
#  'Sudden Girlfriend Appearance',
#  'Gymnastics',
#  'Fetish',
#  'Mansion',
#  'Based on a Movie',
#  'Apocalypse',
#  'Mountain Climbing',
#  'Yaoi',
#  'Gynophobia',
#  'Picture Drama',
#  'Fishing',
#  '16th Century',
#  'Frogs',
#  'Japan Animators Exhibition',
#  'Promotional',
#  'Canada',
#  'Based on a Song',
#  'Ghibli Museum Shorts',
#  'Yuri',
#  'Dragon Quest',
#  'India',
#  'Mysterious Benefactor',
#  'Anime no Chikara',
#  'Kendo',
#  'Inheritance',
#  '17th Century',
#  'Incest',
#  'Bookstore',
#  'Bears',
#  'Zoo',
#  'Romance of the Three Kingdoms',
#  'Stop Motion Animation',
#  'Treasure Hunters',
#  'Rugby',
#  'Landlords',
#  'Borderline H',
#  'Based on a Fairy Tale',
#  'Martial Arts School',
#  'Battle Royale',
#  'Dodgeball',
#  'Divorce',
#  'Alcohol',
#  'Novel Industry',
#  'Badminton',
#  'Lawyers',
#  'Journalism',
#  'Adult Industry',
#  'Urban Legend',
#  'Russia',
#  'Food Protagonists',
#  'Sister Complex',
#  'Golf',
#  'Greece',
#  'Pregnancy',
#  'Commercials',
#  'Disney',
#  'San-X Characters',
#  'Tourism',
#  'Based on a Religious Text',
#  'Anime Bancho',
#  'Australia',
#  'Marvel Comics',
#  'Minna no Uta',
#  'Stockholm Syndrome',
#  'Ga-nime',
#  'Switzerland',
#  'Based on a Picture Book',
#  'CEOs',
#  'Nurses',
#  'Africa',
#  'Convenience Store',
#  'BDSM',
#  'Voyeurism',
#  'Finland',
#  'Japanese Anime Classic Collection',
#  'Modelling',
#  'Smut',
#  'Egyptian Mythology']

# %%
df.loc[(np.array(contains('Tags', ['Student-Teacher Relationship']))) & (np.logical_not(np.array(contains('Tags', ['BL']))))]
# Out:
#        Rating    Votes                                              Title  \
# 1583    7.826   1914.0                                Domestic Girlfriend
# 2052    7.570  17021.0                                     Please Teacher
# 3612    6.762    172.0  Maison Ikkoku: Prelude, When the Cherry Blosso...
# 6052    5.554   2342.0                             Okusama wa Joshikousei
# 8869    3.896    989.0       Omiai Aite wa Oshiego, Tsuyoki na, Mondaiji.
# 11170     NaN      NaN               Why the Hell are You Here, Teacher!?
#
#                                                Alt Title Format  Episodes  \
# 1583                                  Domestic na Kanojo     TV      12.0
# 2052                                      Onegai Teacher     TV      12.0
# 3612   Maison Ikkoku: Prelude - Meguru Haru no Sakura...    OVA       1.0
# 6052                       My Wife is a High School Girl     TV      13.0
# 8869                                                 NaN     TV      12.0
# 11170                          Nande Koko ni Sensei ga!?     TV       NaN
#
#        Duration Start Year End Year         Studio  \
# 1583        NaN     2019.0   2019.0     [diomedea]
# 2052        NaN     2002.0   2002.0        [Daume]
# 3612       28.0     1992.0   1992.0  [Kitty Films]
# 6052        NaN     2005.0   2005.0     [MADHOUSE]
# 8869        5.0     2017.0   2017.0        [Seven]
# 11170       NaN     2019.0   2019.0  [Tear Studio]
#
#                                                     Tags  \
# 1583   [Drama, Romance, Shounen, Animeism, Love Trian...
# 2052   [Ecchi, Romance, Sci Fi, Aliens, School Life, ...
# 3612   [Drama, Romance, Seinen, Student-Teacher Relat...
# 6052   [Ecchi, Romance, Seinen, Married Life, School ...
# 8869   [Josei, Romance, Short Episodes, Smut, Student...
# 11170  [Comedy, Ecchi, Romance, Delinquents, School L...
#
#                                              Description
# 1583   Natsuo is a high school boy who is experiencin...
# 2052   Kei Kusanagi is a shy teenage boy with no roma...
# 3612   Before Kyoko became the manager of Maison Ikko...
# 6052   Asami Onohara is a typical seventeen-year-old ...
# 8869   Late-blooming teacher Nana Saigawa goes to a m...
# 11170  Ichiro Sato is about as average as a student c...
